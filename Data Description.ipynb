# %% [markdown]
# Data Description

# %% [markdown]
# Data Link: https://catalog.data.gov/organization/a7d30359-b403-426c-bc33-a1cf87d8e548?tags=demographics

# %% [markdown]
# We will need more data about the locations, such as the schools, the resteraunts, the types of houses, and other information, so we will use the Foursquare API to retrive
# this data. We will also recieve latitudes and longitudes.
